# %%
import yfinance as yf

# %%
nvda = yf.Ticker("NVDA")

# %%
nvda = nvda.history(period="max")

# %%
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1999-01-22 00:00:00-05:00    0.040119    0.044775    0.035581    0.037612
# 1999-01-25 00:00:00-05:00    0.040597    0.042029    0.037612    0.041552
# 1999-01-26 00:00:00-05:00    0.042029    0.042865    0.037731    0.038328
# 1999-01-27 00:00:00-05:00    0.038447    0.039403    0.036298    0.038209
# 1999-01-28 00:00:00-05:00    0.038209    0.038447    0.037850    0.038089
# ...                               ...         ...         ...         ...
# 2025-04-11 00:00:00-04:00  108.500000  111.550003  107.480003  110.930000
# 2025-04-14 00:00:00-04:00  114.110001  114.290001  109.070000  110.709999
# 2025-04-15 00:00:00-04:00  110.970001  113.620003  110.500000  112.199997
# 2025-04-16 00:00:00-04:00  104.550003  106.790001  100.449997  104.489998
# 2025-04-17 00:00:00-04:00  104.449997  104.470001  100.050003  101.489998
#
#                                Volume  Dividends  Stock Splits
# Date
# ...

# %%
nvda.index
# Out:
# DatetimeIndex(['1999-01-22 00:00:00-05:00', '1999-01-25 00:00:00-05:00',
#                '1999-01-26 00:00:00-05:00', '1999-01-27 00:00:00-05:00',
#                '1999-01-28 00:00:00-05:00', '1999-01-29 00:00:00-05:00',
#                '1999-02-01 00:00:00-05:00', '1999-02-02 00:00:00-05:00',
#                '1999-02-03 00:00:00-05:00', '1999-02-04 00:00:00-05:00',
#                ...
#                '2025-04-04 00:00:00-04:00', '2025-04-07 00:00:00-04:00',
#                '2025-04-08 00:00:00-04:00', '2025-04-09 00:00:00-04:00',
#                '2025-04-10 00:00:00-04:00', '2025-04-11 00:00:00-04:00',
#                '2025-04-14 00:00:00-04:00', '2025-04-15 00:00:00-04:00',
#                '2025-04-16 00:00:00-04:00', '2025-04-17 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=6601, freq=None)

# %%
nvda.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
nvda["Tomorrow"] = nvda["Close"].shift(-1)

# %%
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1999-01-22 00:00:00-05:00    0.040119    0.044775    0.035581    0.037612
# 1999-01-25 00:00:00-05:00    0.040597    0.042029    0.037612    0.041552
# 1999-01-26 00:00:00-05:00    0.042029    0.042865    0.037731    0.038328
# 1999-01-27 00:00:00-05:00    0.038447    0.039403    0.036298    0.038209
# 1999-01-28 00:00:00-05:00    0.038209    0.038447    0.037850    0.038089
# ...                               ...         ...         ...         ...
# 2025-04-11 00:00:00-04:00  108.500000  111.550003  107.480003  110.930000
# 2025-04-14 00:00:00-04:00  114.110001  114.290001  109.070000  110.709999
# 2025-04-15 00:00:00-04:00  110.970001  113.620003  110.500000  112.199997
# 2025-04-16 00:00:00-04:00  104.550003  106.790001  100.449997  104.489998
# 2025-04-17 00:00:00-04:00  104.449997  104.470001  100.050003  101.489998
#
# ...

# %%
nvda["Target"] = (nvda["Tomorrow"] > nvda["Close"]).astype(int)

# %%
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1999-01-22 00:00:00-05:00    0.040119    0.044775    0.035581    0.037612
# 1999-01-25 00:00:00-05:00    0.040597    0.042029    0.037612    0.041552
# 1999-01-26 00:00:00-05:00    0.042029    0.042865    0.037731    0.038328
# 1999-01-27 00:00:00-05:00    0.038447    0.039403    0.036298    0.038209
# 1999-01-28 00:00:00-05:00    0.038209    0.038447    0.037850    0.038089
# ...                               ...         ...         ...         ...
# 2025-04-11 00:00:00-04:00  108.500000  111.550003  107.480003  110.930000
# 2025-04-14 00:00:00-04:00  114.110001  114.290001  109.070000  110.709999
# 2025-04-15 00:00:00-04:00  110.970001  113.620003  110.500000  112.199997
# 2025-04-16 00:00:00-04:00  104.550003  106.790001  100.449997  104.489998
# 2025-04-17 00:00:00-04:00  104.449997  104.470001  100.050003  101.489998
#
# ...

# %%
nvda = nvda.loc["2000-01-01":].copy()

# %%
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2000-01-03 00:00:00-05:00    0.090268    0.090984    0.084297    0.089431
# 2000-01-04 00:00:00-05:00    0.087879    0.088118    0.082625    0.087044
# 2000-01-05 00:00:00-05:00    0.084536    0.085969    0.082984    0.084178
# 2000-01-06 00:00:00-05:00    0.084178    0.084178    0.075462    0.078685
# 2000-01-07 00:00:00-05:00    0.078327    0.080835    0.077134    0.079999
# ...                               ...         ...         ...         ...
# 2025-04-11 00:00:00-04:00  108.500000  111.550003  107.480003  110.930000
# 2025-04-14 00:00:00-04:00  114.110001  114.290001  109.070000  110.709999
# 2025-04-15 00:00:00-04:00  110.970001  113.620003  110.500000  112.199997
# 2025-04-16 00:00:00-04:00  104.550003  106.790001  100.449997  104.489998
# 2025-04-17 00:00:00-04:00  104.449997  104.470001  100.050003  101.489998
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = nvda.iloc[:-100]
test= nvda.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

predictions = model.predict(test[predictors])

# %%
import pandas as pd

predictions = pd.Series(predictions, index=test.index)

# %%
precision_score(test["Target"], predictions)
# Out:
# 0.4935064935064935

# %%
combined = pd.concat([test["Target"], predictions], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#time to add predictors to try to improve our super basic model lol

# %%
nvda["Return"] = nvda["Close"].pct_change()

# %%
nvda["Volatility"] = nvda["Return"].rolling(window=10).std()

# %%
horizons = [2, 5, 60, 250, 1000]

for horizon in horizons:
    rolling_avg = nvda["Close"].rolling(horizon).mean()
    nvda[f"Close_Ratio_{horizon}"] = nvda["Close"] / rolling_avg

# %%
nvda.dropna(inplace=True)

# %%
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2003-12-24 00:00:00-05:00    0.167735    0.168270    0.166130    0.166589
# 2003-12-26 00:00:00-05:00    0.167887    0.174765    0.167199    0.173772
# 2003-12-29 00:00:00-05:00    0.177057    0.181719    0.176217    0.181108
# 2003-12-30 00:00:00-05:00    0.179198    0.184929    0.179044    0.181490
# 2003-12-31 00:00:00-05:00    0.181413    0.182254    0.174383    0.177286
# ...                               ...         ...         ...         ...
# 2025-04-10 00:00:00-04:00  109.370003  110.860001   99.150002  107.570000
# 2025-04-11 00:00:00-04:00  108.500000  111.550003  107.480003  110.930000
# 2025-04-14 00:00:00-04:00  114.110001  114.290001  109.070000  110.709999
# 2025-04-15 00:00:00-04:00  110.970001  113.620003  110.500000  112.199997
# 2025-04-16 00:00:00-04:00  104.550003  106.790001  100.449997  104.489998
#
# ...

# %%
from xgboost import XGBClassifier
from sklearn.metrics import precision_score, accuracy_score
from sklearn.model_selection import train_test_split

# Define all predictors
predictors = [
    "Close", "Volume", "Open", "High", "Low",
    "Close_Ratio_2", "Close_Ratio_5", "Close_Ratio_60",
    "Close_Ratio_250", "Close_Ratio_1000",
    "Return", "Volatility"
]

# Split dataset: last 100 days for testing
train = nvda.iloc[:-100]
test = nvda.iloc[-100:]

# Initialize XGBoost model
model = XGBClassifier(eval_metric='logloss')
model.fit(train[predictors], train["Target"])

# Make predictions on the test set
predictions = model.predict(test[predictors])

# %%
def backtest(data, model, predictors, start=2500, step=250, threshold=0.6):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i + step)].copy()

        # Use custom predict function with threshold
        combined = predict(train, test, predictors, model, threshold)
        all_predictions.append(combined)

    return pd.concat(all_predictions)

# %%
def predict(train, test, predictors, model, threshold=0.6):
    model.fit(train[predictors], train["Target"])

    # Get probabilities of class 1 (stock going up)
    probs = model.predict_proba(test[predictors])[:, 1]

    # Apply threshold
    preds = (probs >= threshold).astype(int)

    # Return combined DataFrame with predictions and actuals
    return pd.DataFrame({
        "Predictions": preds,
        "Actual": test["Target"]
    }, index=test.index)

# %%
# Run it
predictions = backtest(nvda, model, predictors, threshold=0.6)

# Accuracy
accuracy = (predictions["Predictions"] == predictions["Actual"]).mean()
print("Backtest Accuracy with Threshold 0.6:", round(accuracy, 3))
# Out:
# Backtest Accuracy with Threshold 0.6: 0.484

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    1902
# 1     960
# Name: count, dtype: int64

# %%
precision_score(predictions["Actual"], predictions["Predictions"])
# Out:
# 0.5375

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix

# Accuracy
accuracy = (predictions["Predictions"] == predictions["Actual"]).mean()

# Precision
precision = precision_score(predictions["Actual"], predictions["Predictions"])

# Recall
recall = recall_score(predictions["Actual"], predictions["Predictions"])

# Confusion Matrix
cm = confusion_matrix(predictions["Actual"], predictions["Predictions"])

print("Backtest Evaluation Metrics:")
print("----------------------------")
print(f"Accuracy : {round(accuracy, 3)}")
print(f"Precision: {round(precision, 3)}")
print(f"Recall   : {round(recall, 3)}")
print("\nConfusion Matrix:")
print(cm)
# Out:
# Backtest Evaluation Metrics:
# ----------------------------
# Accuracy : 0.484
# Precision: 0.537
# Recall   : 0.333
#
# Confusion Matrix:
# [[ 868  444]
#  [1034  516]]

# %%
import matplotlib.pyplot as plt

# Create a rolling accuracy column
predictions["Correct"] = (predictions["Predictions"] == predictions["Actual"]).astype(int)
rolling_accuracy = predictions["Correct"].rolling(100).mean()

# Plot it
plt.figure(figsize=(12, 6))
plt.plot(rolling_accuracy, label="Rolling Accuracy (100 days)")
plt.title("Model Accuracy Over Time")
plt.xlabel("Date")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
